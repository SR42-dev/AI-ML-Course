# %%
import tensorflow as tf
import matplotlib.pyplot as plt
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
model =tf.keras.models.Sequential(
    [
     tf.keras.layers.Flatten(input_shape = (28,28)),
     tf.keras.layers.Dense(32, activation ='sigmoid'),
     tf.keras.layers.Dense(64, activation ='sigmoid'),
     tf.keras.layers.Dense(10, activation ='softmax')
    ]
)
losss =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer='sgd',loss = losss,metrics=['accuracy'])
history=model.fit(x_train,y_train,epochs = 10,batch_size=10)
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 1.6906 - accuracy: 0.5470
# Epoch 2/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.6893 - accuracy: 0.8172
# Epoch 3/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.6038 - accuracy: 0.8292
# Epoch 4/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.5680 - accuracy: 0.8342
# Epoch 5/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.5515 - accuracy: 0.8325
# Epoch 6/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.5076 - accuracy: 0.8462
# Epoch 7/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.4910 - accuracy: 0.8478
# Epoch 8/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.4977 - accuracy: 0.8488
# Epoch 9/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.4776 - accuracy: 0.8532
# Epoch 10/10
# 6000/6000 [==============================] - 7s 1ms/step - loss: 0.4891 - accuracy: 0.8508
