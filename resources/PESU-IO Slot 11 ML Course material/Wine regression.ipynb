# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline #notebook only cant use in vscod

# %%
df=pd.read_csv('wine.data', names=["Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","Proline"])
df.head()
# Out:
#          Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 1 14.23     1.71        2.43  15.6                127       2.80
#   13.20     1.78        2.14  11.2                100       2.65
#   13.16     2.36        2.67  18.6                101       2.80
#   14.37     1.95        2.50  16.8                113       3.85
#   13.24     2.59        2.87  21.0                118       2.80
#
#          Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 1 14.23           3.06        0.28                  2.29             5.64
#   13.20           2.76        0.26                  1.28             4.38
#   13.16           3.24        0.30                  2.81             5.68
#   14.37           3.49        0.24                  2.18             7.80
#   13.24           2.69        0.39                  1.82             4.32
#
#          Color intensity   Hue  Proline
# 1 14.23             1.04  3.92     1065
#   13.20             1.05  3.40     1050
# ...

# %%
x=df[["Malic acid"]]
x
# Out:
#          Malic acid
# 1 14.23        2.43
#   13.20        2.14
#   13.16        2.67
#   14.37        2.50
#   13.24        2.87
# ...             ...
# 3 13.71        2.45
#   13.40        2.48
#   13.27        2.26
#   13.17        2.37
#   14.13        2.74
#
# [178 rows x 1 columns]

# %%
y=df[["Alcohol"]]
y
# Out:
#          Alcohol
# 1 14.23     1.71
#   13.20     1.78
#   13.16     2.36
#   14.37     1.95
#   13.24     2.59
# ...          ...
# 3 13.71     5.65
#   13.40     3.91
#   13.27     4.28
#   13.17     2.59
#   14.13     4.10
#
# [178 rows x 1 columns]

# %%
plt.scatter(x,y)
