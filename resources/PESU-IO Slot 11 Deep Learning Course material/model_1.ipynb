# %%
import tensorflow as tf
import matplotlib.pyplot as plt
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
model =tf.keras.models.Sequential(
    [
     tf.keras.layers.Flatten(input_shape = (28,28)),
     tf.keras.layers.Dense(320, activation ='sigmoid'),
     tf.keras.layers.Dense(640, activation ='sigmoid'),
     tf.keras.layers.Dense(100, activation ='softmax')
    ]
)
losss =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer='sgd',loss = losss,metrics=['accuracy'])
history=model.fit(x_train,y_train,epochs = 30,batch_size=15)
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 1.2550 - accuracy: 0.6812
# Epoch 2/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.3416 - accuracy: 0.9077
# Epoch 3/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2888 - accuracy: 0.9185
# Epoch 4/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2552 - accuracy: 0.9280
# Epoch 5/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2385 - accuracy: 0.9339
# Epoch 6/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2346 - accuracy: 0.9339
# Epoch 7/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2231 - accuracy: 0.9350
# Epoch 8/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2262 - accuracy: 0.9358
# Epoch 9/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2094 - accuracy: 0.9402
# Epoch 10/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2079 - accuracy: 0.9403
# Epoch 11/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2038 - accuracy: 0.9409
# Epoch 12/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1987 - accuracy: 0.9433
# Epoch 13/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2098 - accuracy: 0.9397
# Epoch 14/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2168 - accuracy: 0.9379
# Epoch 15/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2111 - accuracy: 0.9378
# Epoch 16/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2026 - accuracy: 0.9391
# Epoch 17/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2129 - accuracy: 0.9378
# Epoch 18/30
# 4000/4000 [==============================] - 17s 4ms/step - loss: 0.2165 - accuracy: 0.9375
# Epoch 19/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2080 - accuracy: 0.9379
# Epoch 20/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2008 - accuracy: 0.9412
# Epoch 21/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1969 - accuracy: 0.9426
# Epoch 22/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.2056 - accuracy: 0.9377
# Epoch 23/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1951 - accuracy: 0.9422
# Epoch 24/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1994 - accuracy: 0.9391
# Epoch 25/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1959 - accuracy: 0.9391
# Epoch 26/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1858 - accuracy: 0.9445
# Epoch 27/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1872 - accuracy: 0.9440
# Epoch 28/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1866 - accuracy: 0.9436
# Epoch 29/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1906 - accuracy: 0.9426
# Epoch 30/30
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.1919 - accuracy: 0.9426
